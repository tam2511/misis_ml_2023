# %% [markdown]
# # Машинное обучение
#
# ![image.png](attachment:1bc17566-73b4-41ca-9aa7-5085f16d08a8.png)

# %% [markdown]
# ## Что мы будем изучать?
#
# ### Архитектурные решения задач ML (3 занятия)
#
# ![image.png](attachment:ba551c5d-08e6-4ac7-a77f-3dbf0bd38dad.png)

# %% [markdown]
# - Классические модели ML
#     - Линейные модели
#     - Модели ближайшего соседа
#     - Деревья
#     - Ансамбли
#
# - Нейросети
#     - Полносвязные нейросети
#     - Сверточные нейросети
#     - Реккурентные нейросети
#     - Трансформеры
#     - Генеративные нейросети

# %% [markdown]
# ### Как работать с данными (1 занятие)
#
# ![image.png](attachment:cd9547ef-8051-43af-88f8-aee2f8b022be.png)

# %% [markdown]
# ### Как оценивать модели (1 занятие)
#
# ![Снимок экрана 2023-11-09 в 15.29.44.png](attachment:06a8d1ee-17c1-46ab-8a68-057c61f7336c.png)

# %% [markdown]
# ### Как выводить все ЭТО в продакшн (0.5 занятия)
#
# ![image.png](attachment:defa4463-05cb-430b-8b6d-f306ac2adcc8.png)

# %% [markdown]
# ### Методы поддержки ваших решений (0.5 занятия)
#
# ![image.png](attachment:0632a23a-e549-4176-847c-843a95173a84.png)!

# %% [markdown]
# ### Семинар по системному дизайну машинного обучения (последнее занятие)
#
# ![image.png](attachment:ba869f44-f381-4ee0-96c3-00a085fb6665.png)

# %% [markdown]
# ## Какие домашки будут?
#
# 1. Выстроить пайплайн для предсказания пола, расы и возраста человека по лицу. Обучаем по полученным фичам с нейросети.
# 2. Проводим кластеризацию отзывов с форума.
# 3. Решаем задачу временных рядов.
